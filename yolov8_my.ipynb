# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# %cd {HOME}
# Out:
# /content

# %% [markdown]
# -----------------------------------------------------------
# yolov8n.pt-----model file to be used for object detection. The model file is named "yolov8n.pt."
# -------------------------------------------------------------
#  conf=0.25-----confidence threshold for object detection to 0.25, meaning that only detections with a confidence score greater than or equal to 0.25 will be considered valid.

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/video (2160p).mp4" save=True
# Out:
# 2023-10-19 11:25:22.010967: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-19 11:25:22.893903: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# video 1/1 (1/532) /content/video (2160p).mp4: 384x640 14 persons, 1 umbrella, 1 chair, 66.0ms
# video 1/1 (2/532) /content/video (2160p).mp4: 384x640 13 persons, 1 umbrella, 1 chair, 10.1ms
# video 1/1 (3/532) /content/video (2160p).mp4: 384x640 16 persons, 1 umbrella, 8.4ms
# video 1/1 (4/532) /content/video (2160p).mp4: 384x640 17 persons, 1 umbrella, 1 chair, 8.8ms
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://www.shared.com/content/images/2022/08/guus-baggermans-qjQovsk-9Tc-unsplash-1_GH_content_850px.jpg' save=True
# Out:
# 2023-10-19 10:49:53.388351: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-19 10:49:54.290036: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# ...
# 100% 68.7k/68.7k [00:00<00:00, 333kB/s]
# image 1/1 /content/guus-baggermans-qjQovsk-9Tc-unsplash-1_GH_content_850px.jpg: 352x640 5 persons, 3 bicycles, 1 backpack, 81.2ms
# Speed: 0.5ms pre-process, 81.2ms inference, 126.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
